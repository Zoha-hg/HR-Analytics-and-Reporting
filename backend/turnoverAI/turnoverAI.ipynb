# %% [markdown]
# # Employee Turnover Prediction AI
# This AI will be tasked with first determining employee sentiment based on the filled out feedback forms. This sentiment analysis would then feed into the turnover analysis and predictions.

# %% [markdown]
# ## Step 1: Setup and Connections

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.metrics import AUC, Accuracy

# %% [markdown]
# ## Step 2: Cleaning the Dataset

# %%
df = pd.read_csv('employee_turnover_dataset_2.csv')
# df = pd.read_csv('Employee_Attrition_Dataset.csv')

df['Start Date'] = pd.to_datetime(df['Start Date'])
df['Tenure'] = datetime.now().year - df['Start Date'].dt.year
    
df = pd.get_dummies(df, columns=['Department'], drop_first=True)

df.drop(['Employee ID', 'Start Date'], axis=1, inplace=True)

X = df.drop('Resigned', axis=1)
y = df['Resigned']
    
df.head()
# Out:
#    Satisfaction Level  Age  Years of Experience  Salary  Promotions  Resigned  \
# 0            3.472586   64                   16   57025           1         0
# 1            1.420574   45                    6   95251           0         1
# 2            3.752803   54                    9   74503           0         0
# 3            1.239770   32                    2  104050           0         0
# 4            2.072702   38                    9   58023           0         1
#
#    Tenure  Department_HR  Department_Marketing  Department_Operations  \
# 0      11          False                 False                  False
# 1      27          False                 False                  False
# 2      18           True                 False                  False
# 3       6           True                 False                  False
# 4      17           True                 False                  False
#
#    Department_Sales  Department_Tech
# 0              True            False
# 1              True            False
# 2             False            False
# 3             False            False
# 4             False            False

# %% [markdown]
# ## Step 3: Training the Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, batch_size=1000, validation_split=0.2)
# Out:
# Epoch 1/100
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6350 - loss: 0.6542 - val_accuracy: 0.7501 - val_loss: 0.5112
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7493 - loss: 0.5281 - val_accuracy: 0.7509 - val_loss: 0.5025
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7486 - loss: 0.5202 - val_accuracy: 0.7501 - val_loss: 0.5024
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7540 - loss: 0.5130 - val_accuracy: 0.7501 - val_loss: 0.5026
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7524 - loss: 0.5114 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7537 - loss: 0.5059 - val_accuracy: 0.7501 - val_loss: 0.5017
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7565 - loss: 0.5051 - val_accuracy: 0.7501 - val_loss: 0.5023
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7553 - loss: 0.5049 - val_accuracy: 0.7501 - val_loss: 0.5021
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7543 - loss: 0.5060 - val_accuracy: 0.7501 - val_loss: 0.5018
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7554 - loss: 0.5018 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.5059 - val_accuracy: 0.7501 - val_loss: 0.5017
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7575 - loss: 0.5040 - val_accuracy: 0.7501 - val_loss: 0.5013
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7506 - loss: 0.5087 - val_accuracy: 0.7501 - val_loss: 0.5013
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7561 - loss: 0.5008 - val_accuracy: 0.7501 - val_loss: 0.5011
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.5041 - val_accuracy: 0.7501 - val_loss: 0.5012
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7508 - loss: 0.5060 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7512 - loss: 0.5061 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7571 - loss: 0.5015 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7538 - loss: 0.5038 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7558 - loss: 0.5011 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7557 - loss: 0.5021 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7526 - loss: 0.5015 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.5036 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7532 - loss: 0.5028 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7531 - loss: 0.5039 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7531 - loss: 0.5028 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7538 - loss: 0.5010 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7559 - loss: 0.4972 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7568 - loss: 0.4966 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.5018 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.4991 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7512 - loss: 0.5024 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7563 - loss: 0.4997 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.5014 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7503 - loss: 0.5049 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7530 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.5002 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7527 - loss: 0.5027 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7549 - loss: 0.4997 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7504 - loss: 0.5028 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.4988 - val_accuracy: 0.7501 - val_loss: 0.5004
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7542 - loss: 0.5017 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7547 - loss: 0.5004 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7550 - loss: 0.4975 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.4990 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.5006 - val_accuracy: 0.7504 - val_loss: 0.5005
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7506 - loss: 0.5025 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7569 - loss: 0.4981 - val_accuracy: 0.7502 - val_loss: 0.5007
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7537 - loss: 0.5005 - val_accuracy: 0.7505 - val_loss: 0.5006
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7528 - loss: 0.4987 - val_accuracy: 0.7502 - val_loss: 0.5007
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7529 - loss: 0.5019 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7542 - loss: 0.4972 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7489 - loss: 0.5019 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7542 - loss: 0.4985 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7532 - loss: 0.5001 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.4989 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.4962 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7558 - loss: 0.4988 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7551 - loss: 0.4985 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7527 - loss: 0.4995 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.4998 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7571 - loss: 0.4978 - val_accuracy: 0.7502 - val_loss: 0.5005
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7538 - loss: 0.5003 - val_accuracy: 0.7509 - val_loss: 0.5005
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7533 - loss: 0.5006 - val_accuracy: 0.7503 - val_loss: 0.5007
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7529 - loss: 0.4998 - val_accuracy: 0.7504 - val_loss: 0.5006
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7544 - loss: 0.4965 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7519 - loss: 0.5008 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.4982 - val_accuracy: 0.7506 - val_loss: 0.5005
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7519 - loss: 0.4994 - val_accuracy: 0.7502 - val_loss: 0.5007
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.4991 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7546 - loss: 0.4995 - val_accuracy: 0.7504 - val_loss: 0.5005
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7532 - loss: 0.4975 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.4985 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7566 - loss: 0.4987 - val_accuracy: 0.7503 - val_loss: 0.5005
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7560 - loss: 0.4964 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7534 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7532 - loss: 0.4975 - val_accuracy: 0.7500 - val_loss: 0.5007
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7510 - loss: 0.5009 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7568 - loss: 0.4977 - val_accuracy: 0.7506 - val_loss: 0.5007
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7557 - loss: 0.4996 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7546 - loss: 0.4996 - val_accuracy: 0.7505 - val_loss: 0.5007
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7561 - loss: 0.4959 - val_accuracy: 0.7504 - val_loss: 0.5007
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7527 - loss: 0.4980 - val_accuracy: 0.7504 - val_loss: 0.5008
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7562 - loss: 0.4958 - val_accuracy: 0.7504 - val_loss: 0.5007
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7527 - loss: 0.5007 - val_accuracy: 0.7500 - val_loss: 0.5010
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7510 - loss: 0.4978 - val_accuracy: 0.7501 - val_loss: 0.5012
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7530 - loss: 0.4973 - val_accuracy: 0.7501 - val_loss: 0.5011
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7558 - loss: 0.4975 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7520 - loss: 0.5009 - val_accuracy: 0.7506 - val_loss: 0.5006
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7491 - loss: 0.5026 - val_accuracy: 0.7503 - val_loss: 0.5012
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7541 - loss: 0.4970 - val_accuracy: 0.7507 - val_loss: 0.5005
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7540 - loss: 0.4983 - val_accuracy: 0.7509 - val_loss: 0.5006
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7554 - loss: 0.4972 - val_accuracy: 0.7504 - val_loss: 0.5007
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7542 - loss: 0.4990 - val_accuracy: 0.7504 - val_loss: 0.5006
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7552 - loss: 0.4975 - val_accuracy: 0.7503 - val_loss: 0.5009
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 0.5003 - val_accuracy: 0.7509 - val_loss: 0.5009
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7526 - loss: 0.5024 - val_accuracy: 0.7505 - val_loss: 0.5008
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7523 - loss: 0.4982 - val_accuracy: 0.7502 - val_loss: 0.5010

# %% [markdown]
# ## Testing the Model

# %%
probabilities = model.predict(X_test)
predicted_classes = np.where(probabilities > 0.5, 1, 0)

accuracy = accuracy_score(y_test, predicted_classes)
print(f'Accuracy: {accuracy}')
print(f'Predicted probabilities: {probabilities[:5]}')
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 229us/step
# Accuracy: 0.7533333333333333
# Predicted probabilities: [[0.27398664]
#  [0.29331142]
#  [0.36798567]
#  [0.32876962]
#  [0.07593747]]

# %% [markdown]
# ## Saving the Model

# %%
model.save('AttritionAI.h5')
model.save('AttritionAI.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
