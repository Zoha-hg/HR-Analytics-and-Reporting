# %% [markdown]
# # Employee Turnover Prediction AI
# This AI will be tasked with first determining employee sentiment based on the filled out feedback forms. This sentiment analysis would then feed into the turnover analysis and predictions.

# %% [markdown]
# ## Step 1: Setup and Connections

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.metrics import AUC, Accuracy

# %% [markdown]
# ## Step 2: Cleaning the Dataset

# %%
df = pd.read_csv('employee_turnover_dataset_2.csv')
# df = pd.read_csv('Employee_Attrition_Dataset.csv')

df['Start Date'] = pd.to_datetime(df['Start Date'])
df['Tenure'] = datetime.now().year - df['Start Date'].dt.year

df = pd.get_dummies(df, columns=['Department'], drop_first=True)

df.drop(['Employee ID', 'Start Date'], axis=1, inplace=True)

X = df.drop('Resigned', axis=1)
y = df['Resigned']

# %% [markdown]
# ## Step 3: Training the Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# model = LogisticRegression(max_iter=10000)
# model = RandomForestClassifier(n_estimators=100, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, batch_size=1000, validation_split=0.2)

# model.fit(X_train, y_train)
# Out:
# Epoch 1/100
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6547 - loss: 0.6331 - val_accuracy: 0.7498 - val_loss: 0.5097
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7475 - loss: 0.5252 - val_accuracy: 0.7501 - val_loss: 0.5024
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7502 - loss: 0.5148 - val_accuracy: 0.7503 - val_loss: 0.5023
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7528 - loss: 0.5099 - val_accuracy: 0.7502 - val_loss: 0.5032
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.5105 - val_accuracy: 0.7501 - val_loss: 0.5024
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7538 - loss: 0.5094 - val_accuracy: 0.7501 - val_loss: 0.5025
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7524 - loss: 0.5087 - val_accuracy: 0.7501 - val_loss: 0.5021
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7565 - loss: 0.4997 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7492 - loss: 0.5093 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7515 - loss: 0.5078 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7520 - loss: 0.5055 - val_accuracy: 0.7501 - val_loss: 0.5015
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7536 - loss: 0.5043 - val_accuracy: 0.7501 - val_loss: 0.5017
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7523 - loss: 0.5051 - val_accuracy: 0.7501 - val_loss: 0.5016
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7566 - loss: 0.5031 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7538 - loss: 0.5030 - val_accuracy: 0.7501 - val_loss: 0.5019
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7554 - loss: 0.5055 - val_accuracy: 0.7501 - val_loss: 0.5016
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7572 - loss: 0.4994 - val_accuracy: 0.7501 - val_loss: 0.5013
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7518 - loss: 0.5049 - val_accuracy: 0.7501 - val_loss: 0.5013
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7549 - loss: 0.5001 - val_accuracy: 0.7501 - val_loss: 0.5018
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7561 - loss: 0.5005 - val_accuracy: 0.7501 - val_loss: 0.5014
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7556 - loss: 0.5011 - val_accuracy: 0.7501 - val_loss: 0.5011
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.5037 - val_accuracy: 0.7501 - val_loss: 0.5011
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.5058 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7503 - loss: 0.5045 - val_accuracy: 0.7501 - val_loss: 0.5010
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7546 - loss: 0.5027 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7535 - loss: 0.5045 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - loss: 0.4998 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7556 - loss: 0.4979 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7533 - loss: 0.5039 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7547 - loss: 0.5008 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7551 - loss: 0.4980 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7553 - loss: 0.5024 - val_accuracy: 0.7502 - val_loss: 0.5005
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7561 - loss: 0.4993 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7502 - loss: 0.5023 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7537 - loss: 0.5013 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 0.5024 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7544 - loss: 0.5002 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7506 - loss: 0.5037 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7520 - loss: 0.5016 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.4987 - val_accuracy: 0.7501 - val_loss: 0.5009
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7521 - loss: 0.5016 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7546 - loss: 0.4992 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.5037 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7513 - loss: 0.5033 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7524 - loss: 0.4998 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.4977 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7517 - loss: 0.5012 - val_accuracy: 0.7502 - val_loss: 0.5004
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7498 - loss: 0.5036 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7524 - loss: 0.5009 - val_accuracy: 0.7502 - val_loss: 0.5003
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7553 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7540 - loss: 0.4976 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7509 - loss: 0.5000 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7517 - loss: 0.5007 - val_accuracy: 0.7501 - val_loss: 0.5004
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7573 - loss: 0.4945 - val_accuracy: 0.7503 - val_loss: 0.5003
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7560 - loss: 0.5008 - val_accuracy: 0.7500 - val_loss: 0.5004
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.5007 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7562 - loss: 0.4969 - val_accuracy: 0.7501 - val_loss: 0.5003
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7541 - loss: 0.4972 - val_accuracy: 0.7501 - val_loss: 0.5003
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7537 - loss: 0.5006 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7576 - loss: 0.4949 - val_accuracy: 0.7501 - val_loss: 0.5002
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7516 - loss: 0.5000 - val_accuracy: 0.7503 - val_loss: 0.5003
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.5001 - val_accuracy: 0.7502 - val_loss: 0.5002
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.5001 - val_accuracy: 0.7502 - val_loss: 0.5005
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7517 - loss: 0.4997 - val_accuracy: 0.7503 - val_loss: 0.5004
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7536 - loss: 0.4978 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7554 - loss: 0.4975 - val_accuracy: 0.7504 - val_loss: 0.5003
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.4991 - val_accuracy: 0.7502 - val_loss: 0.5004
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7540 - loss: 0.4999 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7541 - loss: 0.4989 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7532 - loss: 0.5012 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7543 - loss: 0.4979 - val_accuracy: 0.7502 - val_loss: 0.5004
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7525 - loss: 0.5002 - val_accuracy: 0.7503 - val_loss: 0.5004
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7570 - loss: 0.4945 - val_accuracy: 0.7501 - val_loss: 0.5003
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7551 - loss: 0.4964 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7543 - loss: 0.4996 - val_accuracy: 0.7502 - val_loss: 0.5004
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 0.4974 - val_accuracy: 0.7502 - val_loss: 0.5008
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7548 - loss: 0.4994 - val_accuracy: 0.7502 - val_loss: 0.5005
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7573 - loss: 0.4942 - val_accuracy: 0.7501 - val_loss: 0.5008
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7541 - loss: 0.4984 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7554 - loss: 0.4958 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 0.4978 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.4982 - val_accuracy: 0.7501 - val_loss: 0.5006
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.4958 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7528 - loss: 0.4990 - val_accuracy: 0.7503 - val_loss: 0.5005
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7562 - loss: 0.4963 - val_accuracy: 0.7502 - val_loss: 0.5007
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7517 - loss: 0.5007 - val_accuracy: 0.7500 - val_loss: 0.5006
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7551 - loss: 0.4994 - val_accuracy: 0.7501 - val_loss: 0.5003
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7575 - loss: 0.4946 - val_accuracy: 0.7509 - val_loss: 0.5003
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.4981 - val_accuracy: 0.7502 - val_loss: 0.5007
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 0.4996 - val_accuracy: 0.7502 - val_loss: 0.5005
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7554 - loss: 0.4974 - val_accuracy: 0.7504 - val_loss: 0.5004
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7541 - loss: 0.4990 - val_accuracy: 0.7503 - val_loss: 0.5007
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7532 - loss: 0.4976 - val_accuracy: 0.7502 - val_loss: 0.5006
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7522 - loss: 0.5014 - val_accuracy: 0.7501 - val_loss: 0.5007
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7509 - loss: 0.5007 - val_accuracy: 0.7499 - val_loss: 0.5009
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.4971 - val_accuracy: 0.7500 - val_loss: 0.5009
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 0.4991 - val_accuracy: 0.7501 - val_loss: 0.5005
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.4971 - val_accuracy: 0.7503 - val_loss: 0.5004
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 0.5001 - val_accuracy: 0.7508 - val_loss: 0.5006

# %% [markdown]
# ## Testing the Model

# %%
# y_pred = model.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred)
# conf_matrix = confusion_matrix(y_test, y_pred)


# print("Accuracy:", accuracy)
# print("Confusion Matrix:\n", conf_matrix)

loss, accuracy = model.evaluate(X_test, y_test)
print('Test Accuracy:', accuracy)
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - accuracy: 0.7538 - loss: 0.4940
# Test Accuracy: 0.7530999779701233
